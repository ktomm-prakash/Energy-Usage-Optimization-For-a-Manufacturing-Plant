# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"enter your file location")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      1000 non-null   object
#  1   Shift                     1000 non-null   object
#  2   Furnace_ID                1000 non-null   object
#  3   Furnace_Type              1000 non-null   object
#  4   Batch_Type                1000 non-null   object
#  5   Production_Output (tons)  950 non-null    float64
#  6   Energy_Consumption (kWh)  950 non-null    float64
#  7   Furnace_Temperature (°C)  950 non-null    float64
#  8   Annealing_Time (hrs)      950 non-null    float64
#  9   Downtime (hrs)            950 non-null    float64
#  10  Ambient_Temperature (°C)  950 non-null    float64
#  11  Recycled_Content (%)      950 non-null    float64
#  12  Energy_Rating             1000 non-null   object
#  13  Maintenance_Flag          1000 non-null   object
#  14  Fuel_Type                 1000 non-null   object
#  15  Glass_Thickness (mm)      950 non-null    float64
#  16  Production_Target (tons)  950 non-null    float64
#  17  Defects_Percentage (%)    950 non-null    float64
#  18  Melting_Time (hrs)        950 non-null    float64
#  19  Cooling_Energy (kWh)      950 non-null    float64
# dtypes: float64(12), object(8)
# memory usage: 156.4+ KB

# %%
df.columns
# Out:
# Index(['Date', 'Shift', 'Furnace_ID', 'Furnace_Type', 'Batch_Type',
#        'Production_Output (tons)', 'Energy_Consumption (kWh)',
#        'Furnace_Temperature (°C)', 'Annealing_Time (hrs)', 'Downtime (hrs)',
#        'Ambient_Temperature (°C)', 'Recycled_Content (%)', 'Energy_Rating',
#        'Maintenance_Flag', 'Fuel_Type', 'Glass_Thickness (mm)',
#        'Production_Target (tons)', 'Defects_Percentage (%)',
#        'Melting_Time (hrs)', 'Cooling_Energy (kWh)'],
#       dtype='object')

# %%
df.head()
# Out:
#                Date      Shift Furnace_ID Furnace_Type    Batch_Type  \
# 0  01-01-2023 00:00    Morning  Furnace_1     Electric  Borosilicate
# 1  01-01-2023 01:00  Afternoon  Furnace_6       Hybrid     Soda-lime
# 2  01-01-2023 02:00      Night  Furnace_9          Gas          Lead
# 3  01-01-2023 03:00  Afternoon  Furnace_9          Gas     Soda-lime
# 4  01-01-2023 04:00    Morning  Furnace_6     Electric     Soda-lime
#
#    Production_Output (tons)  Energy_Consumption (kWh)  \
# 0                    107.35                   3288.96
# 1                     43.51                   4867.96
# 2                     37.79                   3347.15
# 3                     77.12                   2829.63
# 4                    169.49                   3935.36
#
#    Furnace_Temperature (°C)  Annealing_Time (hrs)  Downtime (hrs)  \
# 0                    1468.9                 30.80            4.19
# 1                    1445.2                  3.68            4.74
# 2                    1486.8                  2.48            2.88
# 3                    1626.8                  1.90            2.41
# 4                    1593.9                  3.81           43.40
#
#    Ambient_Temperature (°C)  Recycled_Content (%) Energy_Rating  \
# 0                      16.7                  56.0             B
# 1                      19.4                   NaN             A
# 2                      20.6                  61.0             B
# 3                      22.6                  51.0             A
# 4                      31.4                   NaN             B
#
#   Maintenance_Flag    Fuel_Type  Glass_Thickness (mm)  \
# 0               No  Natural Gas                  9.79
# 1              Yes  Electricity                  3.45
# 2               No  Electricity                  8.35
# 3               No  Natural Gas                 10.00
# 4              Yes  Natural Gas                  8.60
#
#    Production_Target (tons)  Defects_Percentage (%)  Melting_Time (hrs)  \
# 0                     57.77                    5.55                21.9
# 1                    126.89                    0.48                14.0
# 2                    173.87                    2.54                11.9
# 3                    108.02                    5.96                11.1
# 4                     77.60                     NaN                12.2
#
#    Cooling_Energy (kWh)
# 0                258.78
# 1                707.82
# 2                743.58
# 3                421.00
# 4                275.03

# %%
print(df.dtypes)
# Out:
# Date                         object
# Shift                        object
# Furnace_ID                   object
# Furnace_Type                 object
# Batch_Type                   object
# Production_Output (tons)    float64
# Energy_Consumption (kWh)    float64
# Furnace_Temperature (°C)    float64
# Annealing_Time (hrs)        float64
# Downtime (hrs)              float64
# Ambient_Temperature (°C)    float64
# Recycled_Content (%)        float64
# Energy_Rating                object
# Maintenance_Flag             object
# Fuel_Type                    object
# Glass_Thickness (mm)        float64
# Production_Target (tons)    float64
# Defects_Percentage (%)      float64
# Melting_Time (hrs)          float64
# Cooling_Energy (kWh)        float64
# dtype: object

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# TypeCasting

# %%
# Date

# %%
# df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y %H:%M', errors='coerce')

# %%
# Shift

# %%
# df['Shift'] = df['Shift'].astype('category')
# print(df['Shift'].dtypes)

# %%
# Furnace_ID

# %%
#df['Furnace_ID'] = df['Furnace_ID'].astype('category')
#print(df['Furnace_ID'].dtypes)

# %%
# Furnace_Type

# %%
# df['Furnace_Type'] = df['Furnace_Type'].astype('category')
# print(df['Furnace_Type'].dtypes)

# %%
# Batch_Type

# %%
# df['Batch_Type'] = df['Batch_Type'].astype('category')
# print(df['Batch_Type'].dtypes)

# %%
# Energy_Rating

# %%
# df['Energy_Rating'] = df['Energy_Rating'].astype('category')
# print(df['Energy_Rating'].dtypes)

# %%
# Maintenance_Flag

# %%
# df['Maintenance_Flag'] = df['Maintenance_Flag'].astype('category')
# print(df['Maintenance_Flag'].dtypes)

# %%
# Fuel_Type

# %%
# df['Fuel_Type'] = df['Fuel_Type'].astype('category')
# print(df['Fuel_Type'].dtypes)

# %%
# Production_Output (tons)

# %%
# df['Production_Output (tons)'] = df['Production_Output (tons)'].astype('float')
# print(df['Production_Output (tons)'].dtypes)

# %%
# Energy_Consumption (kWh)

# %%
# df['Energy_Consumption (kWh)'] = df['Energy_Consumption (kWh)'].astype('float')
# print(df['Energy_Consumption (kWh)'].dtypes)

# %%
# Furnace_Temperature (°C)

# %%
# df['Furnace_Temperature (°C)'] = df['Furnace_Temperature (°C)'].astype('float')
# print(df['Furnace_Temperature (°C)'].dtypes)

# %%
# Annealing_Time (hrs)

# %%
# df['Annealing_Time (hrs)'] = df['Annealing_Time (hrs)'].astype('float')
# print(df['Annealing_Time (hrs)'].dtypes)

# %%
# Downtime (hrs)

# %%
# df['Downtime (hrs)'] = df['Downtime (hrs)'].astype('float')
# print(df['Downtime (hrs)'].dtypes)

# %%
# Ambient_Temperature (°C)

# %%
# df['Ambient_Temperature (°C)'] = df['Ambient_Temperature (°C)'].astype('float')
# print(df['Ambient_Temperature (°C)'].dtypes)

# %%
# Recycled_Content (%)

# %%
# df['Recycled_Content (%)'] = df['Recycled_Content (%)'].astype('float')
# print(df['Recycled_Content (%)'].dtypes)

# %%
# Glass_Thickness (mm)

# %%
# df['Glass_Thickness (mm)'] = df['Glass_Thickness (mm)'].astype('float')
# print(df['Glass_Thickness (mm)'].dtypes)

# %%
# Production_Target (tons)

# %%
# df['Production_Target (tons)'] = df['Production_Target (tons)'].astype('float')
# print(df['Production_Target (tons)'].dtypes)

# %%
# Defects_Percentage (%)

# %%
# df['Defects_Percentage (%)'] = df['Defects_Percentage (%)'].astype('float')
# print(df['Defects_Percentage (%)'].dtypes)

# %%
# Melting_Time (hrs)

# %%
# df['Melting_Time (hrs)'] = df['Melting_Time (hrs)'].astype('float')
# print(df['Melting_Time (hrs)'].dtypes)

# %%
# Cooling_Energy (kWh)

# %%
# df['Cooling_Energy (kWh)'] = df['Cooling_Energy (kWh)'].astype('float')
# print(df['Cooling_Energy (kWh)'].dtypes)

# %%
print(df.dtypes)
# Out:
# Date                         object
# Shift                        object
# Furnace_ID                   object
# Furnace_Type                 object
# Batch_Type                   object
# Production_Output (tons)    float64
# Energy_Consumption (kWh)    float64
# Furnace_Temperature (°C)    float64
# Annealing_Time (hrs)        float64
# Downtime (hrs)              float64
# Ambient_Temperature (°C)    float64
# Recycled_Content (%)        float64
# Energy_Rating                object
# Maintenance_Flag             object
# Fuel_Type                    object
# Glass_Thickness (mm)        float64
# Production_Target (tons)    float64
# Defects_Percentage (%)      float64
# Melting_Time (hrs)          float64
# Cooling_Energy (kWh)        float64
# dtype: object

# %% [markdown]
# Handling Duplicate

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Missing Values

# %%
df.isnull().sum()
# Out:
# Date                         0
# Shift                        0
# Furnace_ID                   0
# Furnace_Type                 0
# Batch_Type                   0
# Production_Output (tons)    50
# Energy_Consumption (kWh)    50
# Furnace_Temperature (°C)    50
# Annealing_Time (hrs)        50
# Downtime (hrs)              50
# Ambient_Temperature (°C)    50
# Recycled_Content (%)        50
# Energy_Rating                0
# Maintenance_Flag             0
# Fuel_Type                    0
# Glass_Thickness (mm)        50
# Production_Target (tons)    50
# Defects_Percentage (%)      50
# Melting_Time (hrs)          50
# Cooling_Energy (kWh)        50
# dtype: int64

# %% [markdown]
# Imputing missing values

# %%
# Select the relevant columns and fill missing values with the median
columns_to_fill = [
    'Production_Output (tons)', 'Energy_Consumption (kWh)', 'Furnace_Temperature (°C)', 
    'Annealing_Time (hrs)', 'Downtime (hrs)', 'Ambient_Temperature (°C)', 
    'Recycled_Content (%)', 'Glass_Thickness (mm)', 'Production_Target (tons)', 
    'Defects_Percentage (%)', 'Melting_Time (hrs)', 'Cooling_Energy (kWh)'
]

# Fill missing values with the median of each respective column
df[columns_to_fill] = df[columns_to_fill].fillna(df[columns_to_fill].median())

# %%
df.isnull().sum()
# Out:
# Date                        0
# Shift                       0
# Furnace_ID                  0
# Furnace_Type                0
# Batch_Type                  0
# Production_Output (tons)    0
# Energy_Consumption (kWh)    0
# Furnace_Temperature (°C)    0
# Annealing_Time (hrs)        0
# Downtime (hrs)              0
# Ambient_Temperature (°C)    0
# Recycled_Content (%)        0
# Energy_Rating               0
# Maintenance_Flag            0
# Fuel_Type                   0
# Glass_Thickness (mm)        0
# Production_Target (tons)    0
# Defects_Percentage (%)      0
# Melting_Time (hrs)          0
# Cooling_Energy (kWh)        0
# dtype: int64

# %% [markdown]
# Outlier Tretment

# %%
df.plot(kind="box", sharey=False, sharex=False, subplots=True, figsize=(20,40), layout=[10,2],vert=0)
plt.subplots_adjust(wspace=0.75)

# %%
# Production_Output (tons)

# %%
sns.boxplot(df['Production_Output (tons)'])
# Out:
# <Axes: ylabel='Production_Output (tons)'>

# %%
pip install feature_engine
# Out:
# Requirement already satisfied: feature_engine in c:\users\pbari\anaconda3\lib\site-packages (1.8.1)
# Requirement already satisfied: numpy>=1.18.2 in c:\users\pbari\anaconda3\lib\site-packages (from feature_engine) (1.26.4)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\pbari\anaconda3\lib\site-packages (from feature_engine) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.4.0 in c:\users\pbari\anaconda3\lib\site-packages (from feature_engine) (1.4.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\pbari\anaconda3\lib\site-packages (from feature_engine) (1.13.1)
# Requirement already satisfied: statsmodels>=0.11.1 in c:\users\pbari\anaconda3\lib\site-packages (from feature_engine) (0.14.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pbari\anaconda3\lib\site-packages (from pandas>=2.2.0->feature_engine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pbari\anaconda3\lib\site-packages (from pandas>=2.2.0->feature_engine) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pbari\anaconda3\lib\site-packages (from pandas>=2.2.0->feature_engine) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\pbari\anaconda3\lib\site-packages (from scikit-learn>=1.4.0->feature_engine) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pbari\anaconda3\lib\site-packages (from scikit-learn>=1.4.0->feature_engine) (2.2.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\pbari\anaconda3\lib\site-packages (from statsmodels>=0.11.1->feature_engine) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\pbari\anaconda3\lib\site-packages (from statsmodels>=0.11.1->feature_engine) (23.2)
# Requirement already satisfied: six in c:\users\pbari\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.11.1->feature_engine) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from feature_engine.outliers import Winsorizer

win_df = Winsorizer(capping_method = 'iqr',
                   fold = 1.5,
                   tail = 'both',
                   variables = ['Production_Output (tons)'])

# %%
df = win_df.fit_transform(df)

# %%
sns.boxplot(df['Production_Output (tons)'])
# Out:
# <Axes: ylabel='Production_Output (tons)'>

# %%
# Energy_Consumption (kWh)

# %%
sns.boxplot(df['Energy_Consumption (kWh)'])
# Out:
# <Axes: ylabel='Energy_Consumption (kWh)'>

# %%
from feature_engine.outliers import Winsorizer

win_df = Winsorizer(capping_method = 'iqr',
                   fold = 1.5,
                   tail = 'both',
                   variables = ['Energy_Consumption (kWh)'])

# %%
df = win_df.fit_transform(df)

# %%
sns.boxplot(df['Energy_Consumption (kWh)'])
# Out:
# <Axes: ylabel='Energy_Consumption (kWh)'>

# %%
# Furnace_Temperature (°C)

# %%
sns.boxplot(df['Furnace_Temperature (°C)'])
# Out:
# <Axes: ylabel='Furnace_Temperature (°C)'>

# %%
from feature_engine.outliers import Winsorizer

win_df = Winsorizer(capping_method = 'iqr',
                   fold = 1.5,
                   tail = 'both',
                   variables = ['Furnace_Temperature (°C)'])

# %%
df = win_df.fit_transform(df)

# %%
sns.boxplot(df['Furnace_Temperature (°C)'])
# Out:
# <Axes: ylabel='Furnace_Temperature (°C)'>

# %%
# Annealing_Time (hrs)

# %%
sns.boxplot(df['Annealing_Time (hrs)'])
# Out:
# <Axes: ylabel='Annealing_Time (hrs)'>

# %%
from feature_engine.outliers import Winsorizer

win_df = Winsorizer(capping_method = 'iqr',
                   fold = 1.5,
                   tail = 'both',
                   variables = ['Annealing_Time (hrs)'])

# %%
df = win_df.fit_transform(df)

# %%
sns.boxplot(df['Annealing_Time (hrs)'])
# Out:
# <Axes: ylabel='Annealing_Time (hrs)'>

# %%
# Downtime (hrs)

# %%
sns.boxplot(df['Downtime (hrs)'])
# Out:
# <Axes: ylabel='Downtime (hrs)'>

# %%
from feature_engine.outliers import Winsorizer

win_df = Winsorizer(capping_method = 'iqr',
                   fold = 1.5,
                   tail = 'both',
                   variables = ['Downtime (hrs)'])

# %%
df = win_df.fit_transform(df)

# %%
sns.boxplot(df['Downtime (hrs)'])
# Out:
# <Axes: ylabel='Downtime (hrs)'>

# %%
# Ambient_Temperature (°C)

# %%
sns.boxplot(df['Ambient_Temperature (°C)'])
# Out:
# <Axes: ylabel='Ambient_Temperature (°C)'>

# %%
from feature_engine.outliers import Winsorizer

win_df = Winsorizer(capping_method = 'iqr',
                   fold = 1.5,
                   tail = 'both',
                   variables = ['Ambient_Temperature (°C)'])

# %%
df = win_df.fit_transform(df)

# %%
sns.boxplot(df['Ambient_Temperature (°C)'])
# Out:
# <Axes: ylabel='Ambient_Temperature (°C)'>

# %%
# Recycled_Content (%)

# %%
sns.boxplot(df['Recycled_Content (%)'])
# Out:
# <Axes: ylabel='Recycled_Content (%)'>

# %%
from feature_engine.outliers import Winsorizer

win_df = Winsorizer(capping_method = 'iqr',
                   fold = 1.5,
                   tail = 'both',
                   variables = ['Recycled_Content (%)'])

# %%
df = win_df.fit_transform(df)

# %%
sns.boxplot(df['Recycled_Content (%)'])
# Out:
# <Axes: ylabel='Recycled_Content (%)'>

# %%
# Glass_Thickness (mm)

# %%
sns.boxplot(df['Glass_Thickness (mm)'])
# Out:
# <Axes: ylabel='Glass_Thickness (mm)'>

# %%
from feature_engine.outliers import Winsorizer

win_df = Winsorizer(capping_method = 'iqr',
                   fold = 1.5,
                   tail = 'both',
                   variables = ['Glass_Thickness (mm)'])

# %%
df = win_df.fit_transform(df)

# %%
sns.boxplot(df['Glass_Thickness (mm)'])
# Out:
# <Axes: ylabel='Glass_Thickness (mm)'>

# %%
# Production_Target (tons)

# %%
sns.boxplot(df['Production_Target (tons)'])
# Out:
# <Axes: ylabel='Production_Target (tons)'>

# %%
from feature_engine.outliers import Winsorizer

win_df = Winsorizer(capping_method = 'iqr',
                   fold = 1.5,
                   tail = 'both',
                   variables = ['Production_Target (tons)'])

# %%
df = win_df.fit_transform(df)

# %%
sns.boxplot(df['Production_Target (tons)'])
# Out:
# <Axes: ylabel='Production_Target (tons)'>

# %%
# Defects_Percentage (%)

# %%
sns.boxplot(df['Defects_Percentage (%)'])
# Out:
# <Axes: ylabel='Defects_Percentage (%)'>

# %%
from feature_engine.outliers import Winsorizer

win_df = Winsorizer(capping_method = 'iqr',
                   fold = 1.5,
                   tail = 'both',
                   variables = ['Defects_Percentage (%)'])

# %%
df = win_df.fit_transform(df)

# %%
sns.boxplot(df['Defects_Percentage (%)'])
# Out:
# <Axes: ylabel='Defects_Percentage (%)'>

# %%
# Melting_Time (hrs)

# %%
sns.boxplot(df['Melting_Time (hrs)'])
# Out:
# <Axes: ylabel='Melting_Time (hrs)'>

# %%
from feature_engine.outliers import Winsorizer

win_df = Winsorizer(capping_method = 'iqr',
                   fold = 1.5,
                   tail = 'both',
                   variables = ['Melting_Time (hrs)'])

# %%
df = win_df.fit_transform(df)

# %%
sns.boxplot(df['Melting_Time (hrs)'])
# Out:
# <Axes: ylabel='Melting_Time (hrs)'>

# %%
# Cooling_Energy (kWh)

# %%
sns.boxplot(df['Cooling_Energy (kWh)'])
# Out:
# <Axes: ylabel='Cooling_Energy (kWh)'>

# %%
from feature_engine.outliers import Winsorizer

win_df = Winsorizer(capping_method = 'iqr',
                   fold = 1.5,
                   tail = 'both',
                   variables = ['Cooling_Energy (kWh)'])

# %%
df = win_df.fit_transform(df)

# %%
sns.boxplot(df['Cooling_Energy (kWh)'])
# Out:
# <Axes: ylabel='Cooling_Energy (kWh)'>

# %%
df.plot(kind="box", sharey=False, sharex=False, subplots=True, figsize=(20,40), layout=[10,2],vert=0)
plt.subplots_adjust(wspace=0.75)

# %% [markdown]
# Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df['Production_Output (tons)'] = scaler.fit_transform(df[['Production_Output (tons)']])
print(df)
# Out:
#                  Date      Shift  Furnace_ID Furnace_Type    Batch_Type  \
# 0    01-01-2023 00:00    Morning   Furnace_1     Electric  Borosilicate
# 1    01-01-2023 01:00  Afternoon   Furnace_6       Hybrid     Soda-lime
# 2    01-01-2023 02:00      Night   Furnace_9          Gas          Lead
# 3    01-01-2023 03:00  Afternoon   Furnace_9          Gas     Soda-lime
# 4    01-01-2023 04:00    Morning   Furnace_6     Electric     Soda-lime
# ..                ...        ...         ...          ...           ...
# 995  11-02-2023 11:00  Afternoon   Furnace_1     Electric  Borosilicate
# 996  11-02-2023 12:00      Night  Furnace_10          Gas          Lead
# 997  11-02-2023 13:00      Night   Furnace_7     Electric  Borosilicate
# 998  11-02-2023 14:00    Morning   Furnace_2          Gas     Soda-lime
# 999  11-02-2023 15:00    Morning   Furnace_7          Gas          Lead
#
#      Production_Output (tons)  Energy_Consumption (kWh)  \
# 0                    0.324687                   3288.96
# 1                    0.086516                   4867.96
# 2                    0.065176                   3347.15
# 3                    0.211907                   2829.63
# 4                    0.556516                   3935.36
# ..                        ...                       ...
# 995                  0.297154                    952.61
# 996                  0.015147                   4561.59
# 997                  0.557598                   2291.86
# 998                  0.421500                   4101.09
# 999                  0.111139                   2495.32
#
#      Furnace_Temperature (°C)  Annealing_Time (hrs)  Downtime (hrs)  \
# 0                      1468.9                5.8725           4.190
# 1                      1445.2                3.6800           4.740
# 2                      1486.8                2.4800           2.880
# 3                      1626.8                1.9000           2.410
# 4                      1593.9                3.8100           7.435
# ..                        ...                   ...             ...
# 995                    1540.3                2.0200           0.170
# 996                    1413.5                2.2700           0.330
# 997                    1531.4                2.5600           1.590
# 998                    1555.7                3.7000           4.080
# 999                    1567.3                0.9200           2.850
#
#      Ambient_Temperature (°C)  Recycled_Content (%) Energy_Rating  \
# 0                        16.7                  56.0             B
# 1                        19.4                  39.0             A
# 2                        20.6                  61.0             B
# 3                        22.6                  51.0             A
# 4                        31.4                  39.0             B
# ..                        ...                   ...           ...
# 995                      32.2                  39.0             C
# 996                      38.2                  22.0             C
# 997                      39.4                  39.0             B
# 998                      35.2                  31.0             C
# 999                      31.4                  30.0             C
#
#     Maintenance_Flag    Fuel_Type  Glass_Thickness (mm)  \
# 0                 No  Natural Gas                  9.79
# 1                Yes  Electricity                  3.45
# 2                 No  Electricity                  8.35
# 3                 No  Natural Gas                 10.00
# 4                Yes  Natural Gas                  8.60
# ..               ...          ...                   ...
# 995              Yes  Electricity                 11.73
# 996               No  Electricity                 12.89
# 997              Yes  Natural Gas                 11.50
# 998              Yes  Natural Gas                  3.95
# 999               No  Electricity                  6.43
#
#      Production_Target (tons)  Defects_Percentage (%)  Melting_Time (hrs)  \
# 0                       57.77                    5.55               21.90
# 1                      126.89                    0.48               14.00
# 2                      173.87                    2.54               11.90
# 3                      108.02                    5.96               11.10
# 4                       77.60                    4.84               12.20
# ..                        ...                     ...                 ...
# 995                    197.89                    9.10               11.90
# 996                    174.79                    2.02               16.35
# 997                     31.21                    6.18               18.10
# 998                    173.51                    5.18               12.50
# 999                     44.21                    1.70               15.40
#
#      Cooling_Energy (kWh)
# 0               258.78000
# 1               707.82000
# 2               743.58000
# 3               421.00000
# 4               275.03000
# ..                    ...
# 995             916.04000
# 996             614.99000
# 997             926.40000
# 998             686.49000
# 999            1427.68125
#
# [1000 rows x 20 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# List of columns to scale
columns_to_scale = [
    'Energy_Consumption (kWh)', 'Furnace_Temperature (°C)', 'Annealing_Time (hrs)', 
    'Downtime (hrs)', 'Ambient_Temperature (°C)', 'Recycled_Content (%)', 
    'Glass_Thickness (mm)', 'Production_Target (tons)', 'Defects_Percentage (%)', 
    'Melting_Time (hrs)', 'Cooling_Energy (kWh)'
]

# Apply MinMaxScaler to the selected columns
df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])

# Display the updated DataFrame
print(df)
# Out:
#                  Date      Shift  Furnace_ID Furnace_Type    Batch_Type  \
# 0    01-01-2023 00:00    Morning   Furnace_1     Electric  Borosilicate
# 1    01-01-2023 01:00  Afternoon   Furnace_6       Hybrid     Soda-lime
# 2    01-01-2023 02:00      Night   Furnace_9          Gas          Lead
# 3    01-01-2023 03:00  Afternoon   Furnace_9          Gas     Soda-lime
# 4    01-01-2023 04:00    Morning   Furnace_6     Electric     Soda-lime
# ..                ...        ...         ...          ...           ...
# 995  11-02-2023 11:00  Afternoon   Furnace_1     Electric  Borosilicate
# 996  11-02-2023 12:00      Night  Furnace_10          Gas          Lead
# 997  11-02-2023 13:00      Night   Furnace_7     Electric  Borosilicate
# 998  11-02-2023 14:00    Morning   Furnace_2          Gas     Soda-lime
# 999  11-02-2023 15:00    Morning   Furnace_7          Gas          Lead
#
#      Production_Output (tons)  Energy_Consumption (kWh)  \
# 0                    0.324687                  0.410732
# 1                    0.086516                  0.644191
# 2                    0.065176                  0.419335
# 3                    0.211907                  0.342819
# 4                    0.556516                  0.506304
# ..                        ...                       ...
# 995                  0.297154                  0.065297
# 996                  0.015147                  0.598893
# 997                  0.557598                  0.263308
# 998                  0.421500                  0.530807
# 999                  0.111139                  0.293391
#
#      Furnace_Temperature (°C)  Annealing_Time (hrs)  Downtime (hrs)  \
# 0                    0.152271              1.000000        0.563551
# 1                    0.099817              0.591142        0.637525
# 2                    0.191888              0.367366        0.387357
# 3                    0.501743              0.259207        0.324143
# 4                    0.428927              0.615385        1.000000
# ..                        ...                   ...             ...
# 995                  0.310297              0.281585        0.022865
# 996                  0.029658              0.328205        0.044385
# 997                  0.290599              0.382284        0.213853
# 998                  0.344381              0.594872        0.548756
# 999                  0.370055              0.076457        0.383322
#
#      Ambient_Temperature (°C)  Recycled_Content (%) Energy_Rating  \
# 0                    0.042328              0.466667             B
# 1                    0.113757              0.325000             A
# 2                    0.145503              0.508333             B
# 3                    0.198413              0.425000             A
# 4                    0.431217              0.325000             B
# ..                        ...                   ...           ...
# 995                  0.452381              0.325000             C
# 996                  0.611111              0.183333             C
# 997                  0.642857              0.325000             B
# 998                  0.531746              0.258333             C
# 999                  0.431217              0.250000             C
#
#     Maintenance_Flag    Fuel_Type  Glass_Thickness (mm)  \
# 0                 No  Natural Gas              0.419662
# 1                Yes  Electricity              0.077675
# 2                 No  Electricity              0.341986
# 3                 No  Natural Gas              0.430989
# 4                Yes  Natural Gas              0.355472
# ..               ...          ...                   ...
# 995              Yes  Electricity              0.524307
# 996               No  Electricity              0.586879
# 997              Yes  Natural Gas              0.511901
# 998              Yes  Natural Gas              0.104646
# 999               No  Electricity              0.238420
#
#      Production_Target (tons)  Defects_Percentage (%)  Melting_Time (hrs)  \
# 0                    0.111553                0.389334            0.592751
# 1                    0.389311                0.032386            0.255864
# 2                    0.578099                0.177418            0.166311
# 3                    0.313482                0.418199            0.132196
# 4                    0.191240                0.339347            0.179104
# ..                        ...                     ...                 ...
# 995                  0.674623                0.639268            0.166311
# 996                  0.581796                0.140808            0.356077
# 997                  0.004822                0.433688            0.430704
# 998                  0.576653                0.363284            0.191898
# 999                  0.057062                0.118279            0.315565
#
#      Cooling_Energy (kWh)
# 0                0.118902
# 1                0.457381
# 2                0.484336
# 3                0.241181
# 4                0.131151
# ..                    ...
# 995              0.614333
# 996              0.387407
# 997              0.622143
# 998              0.441302
# 999              1.000000
#
# [1000 rows x 20 columns]

# %%
df.hist(bins=30, figsize=(10, 8),grid=False)
plt.tight_layout()
plt.grid(False)
plt.show()
